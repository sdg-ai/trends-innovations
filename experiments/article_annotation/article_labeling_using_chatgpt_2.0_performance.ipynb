# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %% [markdown]
# # Load Ground Truth

# %%
# load json test_data_annotations.json
with open('test_data_annotations.json') as f:
    ground_truth = json.load(f)
ground_truth
# Out:
# {'0': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '1': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '4': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '5': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '6': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '7': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '8': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '10': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '11': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '13': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '14': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '15': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '16': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '17': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '18': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '19': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '20': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '54': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '55': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '57': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '58': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '59': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '60': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '61': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '62': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '63': ['autonomous_transport'],
#  '64': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '65': ['autonomous_transport', 'autonomous_transport'],
#  '67': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '68': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '71': ['autonomous_transport', 'autonomous_transport'],
#  '72': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '73': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '76': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '77': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '80': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '82': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
# ...
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1396': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1401': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1402': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1403': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1404': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1405': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1406': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1407': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1409': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1410': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1411': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1412': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1789': ['artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence'],
#  '1790': ['artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence'],
#  '1791': ['artificial_intelligence']}

# %% [markdown]
# # Load Predictions

# %%
# load predictions.jsonl from current folder
preds = []
with open("predictions.jsonl") as f:
    lines = f.readlines()
    for idx, line in enumerate(lines):
        try:
            pred =  json.loads(line)
            preds.append(pred)
        except:
            print("Failed to load line")
preds = {list(p.keys())[0]:p[list(p.keys())[0]] for p in preds}
new_rows = []
for article_id, section_predictions in preds.items():
    for section_pred in section_predictions:
        new_row = {
            "article_id": article_id,
            "section_id": section_pred["section_id"],
            "y_hat": section_pred["category"],
            "text": section_pred["text"],
            "reasoning": section_pred["reasoning"],
            "explanation": section_pred["explanation"],
        }
        new_rows.append(new_row)
predictions = pd.DataFrame(new_rows)
# sort by article id and section id
predictions = predictions.sort_values(by=["article_id", "section_id"]).reset_index(drop=True)
predictions.head(n=10)
# Out:
# Failed to load line
#   article_id  section_id               y_hat  \
# 0          0           0  3d_printed_apparel
# 1          0           1  3d_printed_apparel
# 2          0           7  3d_printed_apparel
# 3          0           8  3d_printed_apparel
# 4          0           9  3d_printed_apparel
# 5          0          11         3d_printing
# 6          0          12         3d_printing
# 7          0          13  3d_printed_apparel
# 8          0          14  3d_printed_apparel
# 9          0          15         3d_printing
#
#                                                 text  \
# 0   When the fashion trio threeASFOUR debuted its...
# 1  When the fashion trio threeASFOUR debuted its ...
# 2  The trio at its helm — Gabi Asfour and his des...
# 3  They wanted to do the opposite: stretch clothi...
# 4  They dreamed of 3D-printing textiles that were...
# 5  At a moment when Silicon Valley’s elite are bu...
# 6  But where hoarding cans of Doomsday beans is w...
# 7  Thousands of years of refinement have allowed ...
# 8  But that hasn’t stopped the team behind threeA...
# 9  “With fashion there is the potential to contro...
#
#                                            reasoning  \
# 0  The article segment discusses the debut of a c...
# 1  The article segment focuses on the debut of a ...
# 2  The section specifically mentions the intentio...
# 3  The article segment discusses the dream of 3D-...
# 4  The article segment discusses the concept of 3...
# 5  The section discusses the challenges and limit...
# 6  The article section discusses the challenges a...
# 7  The section discusses the potential to control...
# 8  The article segment discusses the potential of...
# 9  The article section emphasizes the potential o...
#
#                                          explanation
# 0  {'0': {'prediction_1': {'category': '3d_printe...
# 1  {'1': {'prediction_1': {'category': '3d_printi...
# 2  {'0': {'prediction_1': {'category': '3d_printe...
# 3  {'0': {'prediction_1': {'category': '3d_printe...
# 4  {'0': {'prediction_1': {'category': '3d_printe...
# 5  {'1': {'prediction_1': {'category': '3d_printi...
# 6  {'1': {'prediction_1': {'category': '3d_printi...
# 7  {'0': {'prediction_1': {'category': '3d_printe...
# 8  {'0': {'prediction_1': {'category': '3d_printe...
# 9  {'1': {'prediction_1': {'category': '3d_printi...

# %% [markdown]
# ## Add Ground Truth Labels to Predictions

# %%
dfs = []
for article_id, true_labels in ground_truth.items():
    predictions_sub = predictions[predictions["article_id"] == article_id].copy()
    predictions_sub.loc[:, "y"] = true_labels
    # get article level predictions as majority vote of section level predictions
    predictions_sub.loc[:, "article_level_prediction"] = predictions_sub["y"].mode().values[0]
    dfs.append(predictions_sub)
predictions = pd.concat(dfs)
# rename category in true labels
predictions["y"] = predictions["y"].apply(lambda x: "3d_printed_apparel" if x == "3d_printed_clothes" else x)
# change category columns to category type
predictions["y_hat"] = predictions["y_hat"].astype("category")
predictions["y"] = predictions["y"].astype("category")
predictions["article_level_prediction"] = predictions["article_level_prediction"].astype("category")
predictions.head(n=10)
# Out:
#   article_id  section_id               y_hat  \
# 0          0         0.0  3d_printed_apparel
# 1          0         1.0  3d_printed_apparel
# 2          0         7.0  3d_printed_apparel
# 3          0         8.0  3d_printed_apparel
# 4          0         9.0  3d_printed_apparel
# 5          0        11.0         3d_printing
# 6          0        12.0         3d_printing
# 7          0        13.0  3d_printed_apparel
# 8          0        14.0  3d_printed_apparel
# 9          0        15.0         3d_printing
#
#                                                 text  \
# 0   When the fashion trio threeASFOUR debuted its...
# 1  When the fashion trio threeASFOUR debuted its ...
# 2  The trio at its helm — Gabi Asfour and his des...
# 3  They wanted to do the opposite: stretch clothi...
# 4  They dreamed of 3D-printing textiles that were...
# 5  At a moment when Silicon Valley’s elite are bu...
# 6  But where hoarding cans of Doomsday beans is w...
# 7  Thousands of years of refinement have allowed ...
# 8  But that hasn’t stopped the team behind threeA...
# 9  “With fashion there is the potential to contro...
#
#                                            reasoning  \
# 0  The article segment discusses the debut of a c...
# 1  The article segment focuses on the debut of a ...
# 2  The section specifically mentions the intentio...
# 3  The article segment discusses the dream of 3D-...
# 4  The article segment discusses the concept of 3...
# 5  The section discusses the challenges and limit...
# 6  The article section discusses the challenges a...
# 7  The section discusses the potential to control...
# 8  The article segment discusses the potential of...
# 9  The article section emphasizes the potential o...
#
#                                          explanation                   y  \
# 0  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 1  {'1': {'prediction_1': {'category': '3d_printi...  3d_printed_apparel
# 2  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 3  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 4  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 5  {'1': {'prediction_1': {'category': '3d_printi...  3d_printed_apparel
# 6  {'1': {'prediction_1': {'category': '3d_printi...  3d_printed_apparel
# 7  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 8  {'0': {'prediction_1': {'category': '3d_printe...  3d_printed_apparel
# 9  {'1': {'prediction_1': {'category': '3d_printi...  3d_printed_apparel
#
#   article_level_prediction
# 0       3d_printed_clothes
# 1       3d_printed_clothes
# 2       3d_printed_clothes
# 3       3d_printed_clothes
# 4       3d_printed_clothes
# 5       3d_printed_clothes
# 6       3d_printed_clothes
# 7       3d_printed_clothes
# 8       3d_printed_clothes
# 9       3d_printed_clothes

# %% [markdown]
# # Evaluate Results
# ## Predicted Categories that don't exist (should not be possible)

# %%
true_categories = predictions["y"].unique()
unique_non_existing_predictions = predictions[~predictions["y_hat"].isin(true_categories)]["y_hat"].unique()
for cat in unique_non_existing_predictions:
    print(cat)
# Out:
# 3d_printing
# none
# circular_economy
# nan
# 3d_printed_food
# public_transport
# smart_collaboration_tools
# unsure
# carbon_price
# city_planning
# walking
# virtual_reality
# urban_farming
# sharing_economy
# train
# wind_power
# nanotechnology
# sustainable_agriculture_production
# solar_energy
# sustainable_forestry
# sustainable_water_production_treatment
# dematerialisation
# teleworking
# digital_solutions_to_regulate_food_intake_and_nutrition
# videoconferencing
# blockchain
# hydropower
# daylight_architecture
# low_energy_demand
# led
# sustainable_washing
# steel_production
# food_waste_management_solutions
# local_vacations

# %%
true_categories
# Out:
# ['3d_printed_apparel', 'autonomous_transport', 'biking', 'capsule_wardrobe', 'car_sharing', ..., 'rent_apparel', 'sustainable_fabrics', 'organic_food', 'smart_food_management_kitchen_fridges_freezers', 'artificial_intelligence']
# Length: 17
# Categories (17, object): ['3d_printed_apparel', 'artificial_intelligence', 'autonomous_transport', 'biking', ..., 'rent_apparel', 'shipping', 'smart_food_management_kitchen_fridges_freezers', 'sustainable_fabrics']

# %%
print("Percentage of non-existing categories in predictions: {:.2f}%".format(100 * len(predictions[~predictions["y_hat"].isin(true_categories)]) / len(predictions)))
predictions = predictions[~predictions["y_hat"].isin(unique_non_existing_predictions)]
# Out:
# Percentage of non-existing categories in predictions: 35.68%

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(predictions["y"], predictions["y_hat"], labels=true_categories)
cm = pd.DataFrame(cm, index=true_categories, columns=true_categories)

# %%
#from sklearn.metrics import classification_report
#classification_report = classification_report(predictions["y"], predictions["y_hat"], target_names=true_categories, output_dict=True)
#classification_report = pd.DataFrame(classification_report).T
#classification_report

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True") 
plt.title("Confusion Matrix")
plt.show()
