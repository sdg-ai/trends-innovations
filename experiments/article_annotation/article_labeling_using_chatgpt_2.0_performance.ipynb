# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# load json test_data_annotations.json
with open('test_data_annotations.json') as f:
    data = json.load(f)
data
# Out:
# {'0': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '1': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '4': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '5': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '6': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '7': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '8': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '10': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '11': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '13': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '14': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '15': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '16': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '17': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '18': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '19': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '20': ['3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes',
#   '3d_printed_clothes'],
#  '54': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '55': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '57': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '58': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '59': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '60': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '61': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '62': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '63': ['autonomous_transport'],
#  '64': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '65': ['autonomous_transport', 'autonomous_transport'],
#  '67': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '68': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '71': ['autonomous_transport', 'autonomous_transport'],
#  '72': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '73': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '76': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '77': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '80': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport'],
#  '82': ['autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
#   'autonomous_transport',
# ...
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1396': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1401': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1402': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1403': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1404': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1405': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1406': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1407': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1409': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1410': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1411': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1412': ['smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers',
#   'smart_food_management_kitchen_fridges_freezers'],
#  '1789': ['artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence'],
#  '1790': ['artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence',
#   'artificial_intelligence'],
#  '1791': ['artificial_intelligence']}

# %%
# load predictions.jsonl from current folder
with open("predictions.jsonl") as f:
    preds = [json.loads(line) for line in f]
preds = {list(p.keys())[0]:p[list(p.keys())[0]] for p in preds}
new_rows = []
for article_id, section_predictions in preds.items():
    for section_pred in section_predictions:
        new_row = {
            "article_id": article_id,
            "section_id": section_pred["section_id"],
            "section_category": section_pred["category"],
            "text": section_pred["text"],
            "reasoning": section_pred["reasoning"],
            "explanation": section_pred["explanation"],
        }
        new_rows.append(new_row)
predictions = pd.DataFrame(new_rows)
# sort by article id and section id
predictions = predictions.sort_values(by=["article_id", "section_id"]).reset_index(drop=True)
predictions.head(n=10)
# Out:
#   article_id  section_id     section_category  \
# 0          0           0   3d_printed_apparel
# 1          0           1   3d_printed_apparel
# 2          0           7   3d_printed_apparel
# 3          0           8   3d_printed_apparel
# 4          0           9   3d_printed_apparel
# 5          0          11  sustainable_fabrics
# 6          0          12   3d_printed_apparel
# 7          0          13   3d_printed_apparel
# 8          0          14   3d_printed_apparel
# 9          0          15   3d_printed_apparel
#
#                                                 text  \
# 0   When the fashion trio threeASFOUR debuted its...
# 1  When the fashion trio threeASFOUR debuted its ...
# 2  The trio at its helm — Gabi Asfour and his des...
# 3  They wanted to do the opposite: stretch clothi...
# 4  They dreamed of 3D-printing textiles that were...
# 5  At a moment when Silicon Valley’s elite are bu...
# 6  But where hoarding cans of Doomsday beans is w...
# 7  Thousands of years of refinement have allowed ...
# 8  But that hasn’t stopped the team behind threeA...
# 9  “With fashion there is the potential to contro...
#
#                                            reasoning  \
# 0  The section clearly discusses the debut collec...
# 1  The section discusses the debut of a collectio...
# 2  The article segment clearly discusses the crea...
# 3  The section describes the ambition to 3D-print...
# 4  The article segment discusses the dream of cre...
# 5  The article section discusses the efficiency a...
# 6  The section discusses the challenges and innov...
# 7  The article segment emphasizes the potential t...
# 8  The section discusses the potential to control...
# 9  The article segment discusses the potential of...
#
#                                          explanation
# 0  {'1': {'prediction_1': {'category': '3d_printe...
# 1  {'0': {'prediction_1': {'category': 'unsure', ...
# 2  {'1': {'prediction_1': {'category': '3d_printe...
# 3  {'1': {'prediction_1': {'category': '3d_printe...
# 4  {'1': {'prediction_1': {'category': '3d_printe...
# 5  {'0': {'prediction_1': {'category': 'sustainab...
# 6  {'1': {'prediction_1': {'category': '3d_printe...
# 7  {'1': {'prediction_1': {'category': '3d_printe...
# 8  {'0': {'prediction_1': {'category': '3d_printe...
# 9  {'1': {'prediction_1': {'category': '3d_printe...

# %%
dfs = []
for article_id, true_labels in data.items():
    predictions_sub = predictions[predictions["article_id"] == article_id].copy()
    predictions_sub.loc[:, "true_section_category"] = true_labels
    dfs.append(predictions_sub)
predictions = pd.concat(dfs)
predictions.head(n=10)
# rename all elements of "3d_printed_clothes" to "3d_printed_apparel" in true_section_category
predictions["true_section_category"] = predictions["true_section_category"].apply(lambda x: "3d_printed_apparel" if x == "3d_printed_clothes" else x)

# %%
true_categories = predictions["true_section_category"].unique()
# get all unique predictions that are not in true_categories
unique_non_existing_predictions = predictions[~predictions["section_category"].isin(true_categories)]["section_category"].unique()
predictions["section_category"] = predictions["section_category"].apply(lambda x: x if x in true_categories else "other")
unique_non_existing_predictions
# Out:
# array(['3d_printed_fashion', '3d_printing', 'none', '3d_printed_food',
#        'public_transport', 'autonomous transport',
#        'smart_collaboration_tools', 'smart_energy_grids',
#        'autonomous_driving', 'low_impact_living', 'low_energy_demand',
#        'sustainable_water_production_treatment', 'sustainable_forestry',
#        'sustainable_transport', 'sharing_economy',
#        'sustainable_agriculture_production', 'carbon_price',
#        'chemicals_production', 'solar_energy', 'sustainable_washing',
#        'dematerialisation', 'sustainable_construction_materials',
#        'nanotechnology', 'drones', 'modular_design', 'unsure',
#        'scope_for_avoided_emissions', 'air_quality_pollution_control',
#        'health_outcomes_measurement', 'videoconferencing', 'teleworking',
#        'telemedicine', 'blockchain', 'universal_basic_income',
#        'digital_solutions_to_regulate_food_intake_and_nutrition',
#        'healthcare_technology', 'electric_vehicles', 'circular_economy',
#        'electric car', 'electric_vehicles_vs_fuel_efficient_used_cars',
#        'electric_vehicle_incentives', 'led', 'energy_storage',
#        'urban_farming', 'daylight_architecture', 'sustainable_energy',
#        'sustainable_fabric', 'e_learning',
#        'sustainable_energy_production', 'sustainable_shipping',
#        'wind_power', 'sustainable_shipping_cargo_culture',
#        'sustainable_fashion', 'food_waste_management_solutions',
#        'environmental_pollution', 'recycled', 'recycling_technology',
#        'new_living_concepts', 'local_vacations',
#        'sustainable_fashion_textiles', 'internet_of_things',
#        'heating_and_cooling', 'artificial intelligence'], dtype=object)

# %%
confusion_matrix = pd.crosstab(predictions["true_section_category"], predictions["section_category"])
# compute precision, recall, and f1 score and accuracy for each category
precisions = {}
recalls = {}
f1_scores = {}
accuracies = {}
for category in true_categories:
    tp = confusion_matrix.loc[category, category]
    fp = confusion_matrix.loc[category, :].sum() - tp
    fn = confusion_matrix.loc[:, category].sum() - tp
    tn = confusion_matrix.loc[:, :].sum().sum() - tp - fp - fn
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_score = 2 * (precision * recall) / (precision + recall)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precisions[category] = precision
    recalls[category] = recall
    f1_scores[category] = f1_score
    accuracies[category] = accuracy
# pretty print all results
for category in true_categories:
    print(f"Category: {category}")
    print(f"Precision: {precisions[category]:.2f}")
    print(f"Recall: {recalls[category]:.2f}")
    print(f"F1 Score: {f1_scores[category]:.2f}")
    print(f"Accuracy: {accuracies[category]:.2f}")
    print()
# Out:
# Category: 3d_printed_apparel
# Precision: 0.79
# Recall: 0.97
# F1 Score: 0.87
# Accuracy: 0.98
#
# Category: autonomous_transport
# Precision: 0.87
# Recall: 0.87
# F1 Score: 0.87
# Accuracy: 0.97
#
# Category: biking
# Precision: 0.88
# Recall: 0.98
# F1 Score: 0.93
# Accuracy: 0.99
#
# Category: capsule_wardrobe
# Precision: 0.94
# Recall: 1.00
# F1 Score: 0.97
# Accuracy: 1.00
#
# Category: car_sharing
# Precision: 0.68
# Recall: 1.00
# F1 Score: 0.81
# Accuracy: 0.98
#
# Category: cement_production
# Precision: 0.83
# Recall: 1.00
# F1 Score: 0.91
# Accuracy: 1.00
#
# Category: drone
# Precision: 0.64
# Recall: 1.00
# F1 Score: 0.78
# Accuracy: 0.98
#
# Category: e_health
# Precision: 0.82
# Recall: 1.00
# F1 Score: 0.90
# Accuracy: 0.97
#
# Category: electric_car
# Precision: 0.78
# Recall: 1.00
# F1 Score: 0.88
# Accuracy: 0.99
#
# Category: fiber_optic_cables
# Precision: 0.62
# Recall: 1.00
# F1 Score: 0.76
# Accuracy: 0.97
#
# Category: shipping
# Precision: 0.86
# Recall: 0.91
# F1 Score: 0.88
# Accuracy: 0.99
#
# Category: clothes_designed_for_a_circular_economy
# Precision: 0.22
# Recall: 1.00
# F1 Score: 0.36
# Accuracy: 0.95
#
# Category: rent_apparel
# Precision: 0.89
# Recall: 0.98
# F1 Score: 0.93
# Accuracy: 1.00
#
# Category: sustainable_fabrics
# Precision: 0.91
# Recall: 0.77
# F1 Score: 0.84
# Accuracy: 0.97
#
# Category: organic_food
# Precision: 0.86
# Recall: 1.00
# F1 Score: 0.93
# Accuracy: 1.00
#
# Category: smart_food_management_kitchen_fridges_freezers
# Precision: 0.59
# Recall: 0.98
# F1 Score: 0.73
# Accuracy: 0.97
#
# Category: artificial_intelligence
# Precision: 0.94
# Recall: 0.92
# F1 Score: 0.93
# Accuracy: 1.00
