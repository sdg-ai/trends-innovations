# %%
import pandas as pd
import torch
import os
import json
import seaborn as sns
import matplotlib.pyplot as plt
from transformers import AutoTokenizer
from transformers import DistilBertForSequenceClassification
import torch
from tqdm import tqdm
from pickle import load
from sklearn.metrics import confusion_matrix

# %%
device = "cuda"

# %%
# load data form parquet
data = pd.read_parquet("../../training/datasets/chat_gpt_annotated_data.parquet")
data.head()
# Out:
#                                                 text                   label  \
# 0  Is there a case for a basic income guarantee –...  universal_basic_income
# 1  I outline a coherent adjustment framework to a...  universal_basic_income
# 2  Adopting a basic income guarantee in this cont...  universal_basic_income
# 3  Just Transition Framework\nThe Just Transition...  universal_basic_income
# 4  ][Reference: (1996) ‘Sustainable development: ...  universal_basic_income
#
#   spans  article_id  sentence_id
# 0    []        1520            0
# 1    []        1520            1
# 2    []        1520            2
# 3    []        1520            3
# 4    []        1520            4

# %%
model = DistilBertForSequenceClassification.from_pretrained(
            "2024-02-02-distilbert-base-uncased/seed_1", 
            local_files_only=True
).to(device)
tokenizer = AutoTokenizer.from_pretrained(f"./2024-02-02-distilbert-base-uncased", local_files_only=True)
le = load(open(f'2024-02-02-distilbert-base-uncased/label_encoder.pkl', 'rb'))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
predictions = []
for idx, row in tqdm(data.iterrows(), total=len(data)):
    encoded_text = tokenizer(
    row.text,
    return_tensors="pt",
    truncation=True,
    padding=True,
    max_length=512
    )
    encoded_text = encoded_text.to(device)
    output = model(**encoded_text, output_attentions=False, output_hidden_states=False)
    class_probs = torch.nn.Softmax(dim=1)(output.logits)
    prediction = torch.argmax(class_probs, dim=1)
    predictions.append(prediction)
# Out:
# 100%|██████████| 18750/18750 [02:30<00:00, 124.29it/s]

# %%
predictions = [le.inverse_transform([x.item()])[0] for x in predictions]
data["predictions"] = predictions

# %%
plt.figure(figsize=(30, 30))
# create confusion matrix with the predictions the labels (sklearn)
cm  = confusion_matrix(data["label"], data["predictions"], labels=le.classes_)
sns.heatmap(cm, annot=True, fmt="d", xticklabels=le.classes_, yticklabels=le.classes_)
# Out:
# <Axes: >

# %%
true_labels = data['label'].unique()
predicted_labels = data['predictions'].unique()
missing_labels = set(true_labels) - set(predicted_labels)
print("Labels with no predictions:", missing_labels)
# Out:
# Labels with no predictions: {'urban_farming', 'low-energy-demand', 'chemicals_production', 'meat_shame', 'heating_&_cooling', 'food_waste_management_solutions', 'digital_solutions_to_regulate_food_intake_and_nutrition', 'led', 'wind_power', 'flight_shame', 'grid_parity', 'sharing_economy', 'steel_production', 'insulation', 'compact_living'}

# %%
# compute per class accuracy, precision, recall and f1 (get a summary)
from sklearn.metrics import classification_report
performance = classification_report(data["label"], data["predictions"], target_names=le.classes_, zero_division=0.0, output_dict=True)
# print performance by descending f1
performance = pd.DataFrame(performance)
performance.T
# Out:
#                                                     precision    recall  \
# 3d_printed_apparel                                   0.980022  0.969265
# 3d_printed_food                                      0.920000  0.657143
# animal_rights                                        0.848665  0.890966
# artificial_intelligence                              0.824219  0.850806
# autonomous_transport                                 0.977273  0.948226
# biking                                               0.965087  0.972362
# blockchain                                           0.851852  0.522727
# capsule_wardrobe                                     0.890625  0.990074
# car-sharing                                          0.937500  0.945946
# carbon_price                                         0.777778  0.501887
# cement_production                                    0.926471  0.959391
# chemicals_production                                 0.000000  0.000000
# circular_economy                                     0.706977  0.649573
# city_planning                                        0.788845  0.905488
# clothes_designed_for_a_circular_economy              0.944444  0.644087
# compact_living                                       0.000000  0.000000
# dematerialisation                                    0.837349  0.868750
# digital_solutions_to_regulate_food_intake_and_n...   0.000000  0.000000
# drone                                                0.971963  0.982987
# e-health                                             0.988095  0.992032
# ecosophy                                             0.861933  0.915183
# electric_car                                         0.907104  0.967930
# energy_storage                                       0.646809  0.678571
# fiber_optic_cables                                   0.961481  0.973013
# flight_shame                                         0.000000  0.000000
# food_waste_management_solutions                      0.000000  0.000000
# grid_parity                                          0.000000  0.000000
# half-earth                                           0.596288  0.810726
# heating_&_cooling                                    0.000000  0.000000
# insulation                                           0.000000  0.000000
# led                                                  0.000000  0.000000
# local_vacations                                      0.765306  0.903614
# low-energy-demand                                    0.000000  0.000000
# low_impact_living                                    0.691176  0.510870
# meat_shame                                           0.000000  0.000000
# meatfree/plant_based_(biotech)                       0.631579  0.765957
# modular_design                                       0.250000  0.036364
# nanotechnology                                       0.869565  0.943396
# organic_food                                         0.982684  0.991266
# public_transport                                     0.781553  0.693966
# rent_apparel                                         0.972527  0.936508
# scope_4/avoided_emissions                            0.789439  0.880707
# sharing_economy                                      0.000000  0.000000
# shipping                                             0.941860  0.961995
# smart_collaboration_tools                            1.000000  0.117647
# smart_energy_grids                                   0.868833  0.923274
# smart_food_management/kitchen/fridges/freezers       0.958092  0.982222
# solar_energy                                         0.572792  0.902256
# steel_production                                     0.000000  0.000000
# sustainable_agriculture_production                   0.713675  0.769585
# sustainable_fabrics                                  0.811786  0.964975
# sustainable_forestry                                 0.813278  0.481572
# sustainable_water_production/treatment               0.857143  0.529412
# universal_basic_income                               0.764706  0.925094
# urban_farming                                        0.000000  0.000000
# vegan_food                                           0.764706  0.485981
# wind_power                                           0.000000  0.000000
# accuracy                                             0.862773  0.862773
# macro avg                                            0.612482  0.584277
# weighted avg                                         0.849108  0.862773
#
#                                                     f1-score       support
# 3d_printed_apparel                                  0.974614    911.000000
# 3d_printed_food                                     0.766667     35.000000
# animal_rights                                       0.869301    321.000000
# artificial_intelligence                             0.837302    248.000000
# autonomous_transport                                0.962530   1043.000000
# biking                                              0.968711    398.000000
# blockchain                                          0.647887     44.000000
# capsule_wardrobe                                    0.937720    403.000000
# car-sharing                                         0.941704    444.000000
# carbon_price                                        0.610092    265.000000
# cement_production                                   0.942643    197.000000
# chemicals_production                                0.000000     16.000000
# circular_economy                                    0.677060    468.000000
# city_planning                                       0.843151    656.000000
# clothes_designed_for_a_circular_economy             0.765870    871.000000
# compact_living                                      0.000000     19.000000
# dematerialisation                                   0.852761    160.000000
# digital_solutions_to_regulate_food_intake_and_n...  0.000000     32.000000
# drone                                               0.977444    529.000000
# e-health                                            0.990060   1506.000000
# ecosophy                                            0.887760    955.000000
# electric_car                                        0.936530    343.000000
# energy_storage                                      0.662309    224.000000
# fiber_optic_cables                                  0.967213    667.000000
# flight_shame                                        0.000000     21.000000
# food_waste_management_solutions                     0.000000     30.000000
# grid_parity                                         0.000000     73.000000
# half-earth                                          0.687166    317.000000
# heating_&_cooling                                   0.000000     14.000000
# insulation                                          0.000000     11.000000
# led                                                 0.000000     11.000000
# local_vacations                                     0.828729     83.000000
# low-energy-demand                                   0.000000     42.000000
# low_impact_living                                   0.587500     92.000000
# meat_shame                                          0.000000     34.000000
# meatfree/plant_based_(biotech)                      0.692308    188.000000
# modular_design                                      0.063492     55.000000
# nanotechnology                                      0.904977    106.000000
# organic_food                                        0.986957    229.000000
# public_transport                                    0.735160    232.000000
# rent_apparel                                        0.954178    189.000000
# scope_4/avoided_emissions                           0.832579   1358.000000
# sharing_economy                                     0.000000     30.000000
# shipping                                            0.951821    421.000000
# smart_collaboration_tools                           0.210526     17.000000
# smart_energy_grids                                  0.895226    782.000000
# smart_food_management/kitchen/fridges/freezers      0.970007    675.000000
# solar_energy                                        0.700730    266.000000
# steel_production                                    0.000000     15.000000
# sustainable_agriculture_production                  0.740576    434.000000
# sustainable_fabrics                                 0.881777   1399.000000
# sustainable_forestry                                0.604938    407.000000
# sustainable_water_production/treatment              0.654545     34.000000
# universal_basic_income                              0.837288    267.000000
# urban_farming                                       0.000000     20.000000
# vegan_food                                          0.594286    107.000000
# wind_power                                          0.000000     36.000000
# accuracy                                            0.862773      0.862773
# macro avg                                           0.584809  18750.000000
# weighted avg                                        0.850177  18750.000000
